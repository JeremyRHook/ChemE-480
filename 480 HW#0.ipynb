# %%
# 480 Homework 0

# %%
#Problem 2
# From a python notebook using the print staement display "Hello world"

print("Hello world")
# Out:
# Hello world

# %%
#Problem 3
#Plot your favorite function $y(t)$ vs $t$ in the same notebook $(sin, cos, x^3, exp...$ for example)
#For an example see the template in Gradescope

import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(-5,5,100)
yt = np.sin(t)

plt.plot(t,yt)
